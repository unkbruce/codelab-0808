# %% [markdown]
# <a href="https://colab.research.google.com/github/unkbruce/codelab-0808/blob/master/scratchpad%EC%9D%98_%EC%82%AC%EB%B3%B8.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
data = input("내일은 무슨요일")
data
# Out:
# 내일은 무슨요일수
# '수'
